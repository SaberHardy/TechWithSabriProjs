# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('banking_data.csv')
plt.style.use('seaborn')
# Out:
# /var/folders/hq/d8slpm_j4nz909tpjh8xrpmr0000gn/T/ipykernel_8202/3994826288.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
plt.figure(figsize=(15, 10))

# %% [markdown]
# ### 1. Order Price Distribution

# %%
df.head(3)
# Out:
#    Review_ID   Customer_Name        Date  Rating  \
# 0          1  Roberto Dalton  2024-11-10       4
# 1          2    Robert Duran  2023-10-15       2
# 2          3  Jason Gonzalez  2023-03-03       4
#
#                                          Review_Text  Visit_Count  \
# 0  Newspaper student glass when trip large reason...            9
# 1  Nature particular long level within occur late...           10
# 2  Him hard some require crime social movement st...           12
#
#   Item_Ordered  Order_Price  Wait_Time_Minutes Service_Quality
# 0        Salad         6.23                 22            Poor
# 1          Tea         3.78                 12       Excellent
# 2       Coffee        15.95                 12            Poor

# %%
sns.kdeplot(data=df, x='Order_Price', fill=True, color='skyblue')
ax1.set_title('Distribution of Order Prices')
ax1.set_xlabel('Order Price ($)')
ax1.set_ylabel('Density')
# Out:
# Text(4.444444444444452, 0.5, 'Density')

# %%
sns.kdeplot(data=df, x='Wait_Time_Minutes', fill=True, color='lightgreen')
ax2.set_title('Distribution of Wait Times')
ax2.set_xlabel('Wait Time (Minutes)')
ax2.set_ylabel('Density')
# Out:
# Text(638.5353535353535, 0.5, 'Density')

# %%
sns.kdeplot(data=df, x='Visit_Count', fill=True, color='salmon')
ax3.set_title('Distribution of Visit Counts')
ax3.set_xlabel('Number of Visits')
ax3.set_ylabel('Density')
# Out:
# Text(4.444444444444452, 0.5, 'Density')

# %%
sns.kdeplot(data=df, x='Rating', fill=True, color='purple')
ax4.set_title('Distribution of Ratings')
ax4.set_xlabel('Rating')
ax4.set_ylabel('Density')
# Out:
# Text(638.5353535353535, 0.5, 'Density')

# %%
plt.suptitle('Density Plots of Customer Metrics', fontsize=16, y=1.02)
# Out:
# Text(0.5, 1.02, 'Density Plots of Customer Metrics')

# %%
plt.tight_layout()

# %%
plt.show()
