# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %%
my_numbers = randn(4, 3) # 4 rows, 3 columns
my_rows = ["One", "Two", "Three", "Four"]
my_header = ['Monday', 'Tuesday', 'Friday']

# %%
my_numbers
# Out:
# array([[-1.77579494,  0.14366991,  0.44623099],
#        [-1.49928003,  1.14846937, -0.03086324],
#        [-0.80161375, -0.91812362,  0.75507169],
#        [ 0.55962615,  0.8411771 , -0.15192361]])

# %%
my_rows
# Out:
# ['One', 'Two', 'Three', 'Four']

# %%
type(my_header)
# Out:
# list

# %%
df = pd.DataFrame(my_numbers, my_rows, my_header)
df
# Out:
#          Monday   Tuesday    Friday
# One   -1.074693 -0.740902 -0.087926
# Two   -2.000182 -0.190144 -0.955044
# Three -1.782655  1.412082  0.794293
# Four   0.143570  1.153781  1.452292

# %%
cust_df = pd.read_csv("customers.csv")
cust_df.head(5)
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
cust_df.tail(5)
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
cust_df.shape
# Out:
# (100, 12)

# %%
cust_df['Customer Id']
# Out:
# 0     DD37Cf93aecA6Dc
# 1     1Ef7b82A4CAAD10
# 2     6F94879bDAfE5a6
# 3     5Cef8BFA16c5e3c
# 4     053d585Ab6b3159
#            ...
# 95    cb8E23e48d22Eae
# 96    CeD220bdAaCfaDf
# 97    28CDbC0dFe4b1Db
# 98    c23d1D9EE8DEB0A
# 99    2354a0E336A91A1
# Name: Customer Id, Length: 100, dtype: object

# %%
cust_df['Company'].head(10)
# Out:
# 0                    Rasmussen Group
# 1                        Vega-Gentry
# 2                      Murillo-Perry
# 3    Dominguez, Mcmillan and Donovan
# 4           Martin, Lang and Andrade
# 5                       Steele Group
# 6       Lester, Woodard and Mitchell
# 7       Sanford, Davenport and Giles
# 8                     Browning-Simon
# 9                       Beck-Hendrix
# Name: Company, dtype: object

# %%
cust_df[['City', 'Email']].head()
# Out:
#                 City                        Email
# 0       East Leonard     zunigavanessa@smith.info
# 1  East Jimmychester              vmata@colon.com
# 2      Isabelborough          beckycarr@hogan.com
# 3         Bensonview  stanleyblackwell@benson.org
# 4     West Priscilla      colinalvarado@miles.net

# %%
cust_df.dtypes
# Out:
# Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# dtype: object

# %%
cust_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
#  2   First Name         100 non-null    object
#  3   Last Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone 1            100 non-null    object
#  8   Phone 2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB

# %%
cust_df.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
cust_df.describe(include="all")
# Out:
#              Index      Customer Id First Name Last Name    Company  \
# count   100.000000              100        100       100        100
# unique         NaN              100         93        97         99
# top            NaN  DD37Cf93aecA6Dc     Sheryl     Greer  Simon LLC
# freq           NaN                1          2         2          2
# mean     50.500000              NaN        NaN       NaN        NaN
# std      29.011492              NaN        NaN       NaN        NaN
# min       1.000000              NaN        NaN       NaN        NaN
# 25%      25.750000              NaN        NaN       NaN        NaN
# 50%      50.500000              NaN        NaN       NaN        NaN
# 75%      75.250000              NaN        NaN       NaN        NaN
# max     100.000000              NaN        NaN       NaN        NaN
#
#                 City          Country       Phone 1           Phone 2  \
# count            100              100           100               100
# ...

# %%
cust_df['First Name'].describe()
# Out:
# count        100
# unique        93
# top       Sheryl
# freq           2
# Name: First Name, dtype: object

# %%
cust_df.iloc[:, 2]
# Out:
# 0       Sheryl
# 1      Preston
# 2          Roy
# 3        Linda
# 4       Joanna
#         ...
# 95        Karl
# 96        Lynn
# 97        Fred
# 98      Yvonne
# 99    Clarence
# Name: First Name, Length: 100, dtype: object

# %%
cust_df.head(2)
# Out:
#    Index      Customer Id First Name Last Name          Company  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter  Rasmussen Group
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano      Vega-Gentry
#
#                 City   Country       Phone 1           Phone 2  \
# 0       East Leonard     Chile  229.077.5154  397.884.0519x718
# 1  East Jimmychester  Djibouti    5153435776  686-620-1820x944
#
#                       Email Subscription Date                     Website
# 0  zunigavanessa@smith.info        2020-08-24  http://www.stephenson.com/
# 1           vmata@colon.com        2021-04-23       http://www.hobbs.com/

# %%
cust_df.loc[1]
# Out:
# Index                                    2
# Customer Id                1Ef7b82A4CAAD10
# First Name                         Preston
# Last Name                           Lozano
# Company                        Vega-Gentry
# City                     East Jimmychester
# Country                           Djibouti
# Phone 1                         5153435776
# Phone 2                   686-620-1820x944
# Email                      vmata@colon.com
# Subscription Date               2021-04-23
# Website              http://www.hobbs.com/
# Name: 1, dtype: object

# %%
# import pandas as pd
# import numpy as np

# # Create a list of column names
# columns = ['Name', 'Age', 'City', 'Salary', 'Is_Employed']

# # Generate random data with null values
# data = [
#     ['John', 30, 'New York', np.nan, True],
#     ['Jane', 25, 'Los Angeles', 50000, False],
#     [np.nan, 40, 'Chicago', 60000, True],
#     ['Mike', 35, np.nan, 70000, False],
#     ['Emily', np.nan, 'Houston', 80000, True],
#     ['David', 45, 'Phoenix', np.nan, False],
#     ['Sarah', 30, 'Dallas', 55000, True],
#     ['Chris', 25, 'Seattle', 65000, False],
#     [np.nan, 40, 'Denver', 75000, True],
#     ['Olivia', 35, 'San Francisco', np.nan, False]
# ]

# # Create a DataFrame
# df = pd.DataFrame(data, columns=columns)

# # Save the DataFrame to a CSV file
# df.to_csv('sample_data.csv', index=False)
